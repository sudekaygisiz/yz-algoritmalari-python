# %% [markdown]
# <a href="https://colab.research.google.com/github/sudekaygisiz/yz-algoritmalari-python/blob/main/ilk-ders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Scikit-learn kütüphanesini Python ortamınıza yüklemek için kullanmanız gereken temel komut şudur:**

# %%
pip install scikit-learn
